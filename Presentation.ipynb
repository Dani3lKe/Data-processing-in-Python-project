# %% [markdown]
# # Python project:
# ## Intraday patterns of the price impact coefficient in the Bitcoin market

# %% [markdown]
# Marek Erben, Daniel Kessler

# %%
#If needed, run: pip install statsmodels

# %%
#We load essential instruments. This cell needs to be run only once.
from DataPreparation import *
from Analysis import *

# %%
'''
Please provide the desired parameters, and we will present the results in both numerical and graphical formats.

Parameters
----------
start_date : str
    The start date in the format 'YYYY-MM-DD'. In range from '2020-11-15' to '2020-11-30'.

end_date : str
    The end date in the format 'YYYY-MM-DD'. In range from '2020-11-15' to '2020-11-30'.
'''

start_date = '2020-11-15'
end_date = '2020-11-30'

# %%
'''
Observe numerical results.
'''
finished_df(start_date, end_date)
# Out:
#                      beta_coef  avg_depth
# 2020-11-15 00:00:00   8.511316   2.092360
# 2020-11-15 00:30:00   3.540263   3.729058
# 2020-11-15 01:00:00   4.862638   2.544201
# 2020-11-15 01:30:00   4.593682   3.847838
# 2020-11-15 02:00:00   4.311434   3.613072
# ...                        ...        ...
# 2020-11-30 21:30:00  13.168741   1.330951
# 2020-11-30 22:00:00  17.367836   0.909591
# 2020-11-30 22:30:00   7.966911   1.594617
# 2020-11-30 23:00:00   9.902736   1.904186
# 2020-11-30 23:30:00  10.724311   2.281204
#
# [768 rows x 2 columns]

# %%
'''
Observe graphical results.
'''
get_graph(finished_df(start_date, end_date))
